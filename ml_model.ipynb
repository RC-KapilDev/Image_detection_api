# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Define path to the image file
results = model.predict('https://i.pcmag.com/imagery/reviews/02lcg0Rt9G3gSqCpWhFG0o1-2.fit_lim.size_840x473.v1656623239.jpg')
result=results[0]

# Run inference on the source


for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:02<00:00, 2.26MB/s]
#
# Downloading https://i.pcmag.com/imagery/reviews/02lcg0Rt9G3gSqCpWhFG0o1-2.fit_lim.size_840x473.v1656623239.jpg to '02lcg0Rt9G3gSqCpWhFG0o1-2.fit_lim.size_840x473.v1656623239.jpg'...
# 51.6kB [00:00, 161kB/s]
# image 1/1 c:\competationapi\02lcg0Rt9G3gSqCpWhFG0o1-2.fit_lim.size_840x473.v1656623239.jpg: 384x640 1 laptop, 101.7ms
# Speed: 2.1ms preprocess, 101.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Object type: laptop
# Coordinates: [110, 12, 719, 464]
# Probability: 0.94
# ---

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=840x473>
